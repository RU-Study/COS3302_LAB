# %% [markdown]
# # Import Lib and Data and Config

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate

# %%
data_training = pd.read_csv("./datatraining.txt")
data_test_1 = pd.read_csv("./datatest.txt")
data_test_2 = pd.read_csv("./datatest2.txt")

# %%
p_color = '#e9c7c6'
s_color = '#4c4b49'
t_color = '#4c4b49'

# %% [markdown]
# # Overview of the dataset

# %% [markdown]
# ## data_training

# %%
data_training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8143 entries, 0 to 8142
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             8143 non-null   int64
#  1   date           8143 non-null   object
#  2   Temperature    8143 non-null   float64
#  3   Humidity       8143 non-null   float64
#  4   Light          8143 non-null   float64
#  5   CO2            8143 non-null   float64
#  6   HumidityRatio  8143 non-null   float64
#  7   Occupancy      8143 non-null   int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 509.1+ KB

# %%
data_training.head(8143)
# Out:
#         id                 date  Temperature  Humidity  Light         CO2  \
# 0        1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.250000
# 1        2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.000000
# 2        3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.500000
# 3        4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.250000
# 4        5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.500000
# ...    ...                  ...          ...       ...    ...         ...
# 8138  8139  2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000
# 8139  8140  2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000
# 8140  8141  2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000
# 8141  8142  2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333
# 8142  8143  2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000
#
#       HumidityRatio  Occupancy
# 0          0.004793          1
# 1          0.004783          1
# 2          0.004779          1
# 3          0.004772          1
# 4          0.004757          1
# ...             ...        ...
# 8138       0.005579          1
# 8139       0.005563          1
# 8140       0.005596          1
# 8141       0.005621          1
# 8142       0.005612          1
#
# [8143 rows x 8 columns]

# %% [markdown]
# ## data_test_1

# %%
data_test_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665 entries, 0 to 2664
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             2665 non-null   int64
#  1   date           2665 non-null   object
#  2   Temperature    2665 non-null   float64
#  3   Humidity       2665 non-null   float64
#  4   Light          2665 non-null   float64
#  5   CO2            2665 non-null   float64
#  6   HumidityRatio  2665 non-null   float64
#  7   Occupancy      2665 non-null   int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 166.7+ KB

# %%
data_test_1.head(2665)
# Out:
#         id                 date  Temperature   Humidity       Light  \
# 0      140  2015-02-02 14:19:00    23.700000  26.272000  585.200000
# 1      141  2015-02-02 14:19:59    23.718000  26.290000  578.400000
# 2      142  2015-02-02 14:21:00    23.730000  26.230000  572.666667
# 3      143  2015-02-02 14:22:00    23.722500  26.125000  493.750000
# 4      144  2015-02-02 14:23:00    23.754000  26.200000  488.600000
# ...    ...                  ...          ...        ...         ...
# 2660  2800  2015-02-04 10:38:59    24.290000  25.700000  808.000000
# 2661  2801  2015-02-04 10:40:00    24.330000  25.736000  809.800000
# 2662  2802  2015-02-04 10:40:59    24.330000  25.700000  817.000000
# 2663  2803  2015-02-04 10:41:59    24.356667  25.700000  813.000000
# 2664  2804  2015-02-04 10:43:00    24.408333  25.681667  798.000000
#
#               CO2  HumidityRatio  Occupancy
# 0      749.200000       0.004764          1
# 1      760.400000       0.004773          1
# 2      769.666667       0.004765          1
# 3      774.750000       0.004744          1
# 4      779.000000       0.004767          1
# ...           ...            ...        ...
# 2660  1150.250000       0.004829          1
# 2661  1129.200000       0.004848          1
# 2662  1125.800000       0.004841          1
# 2663  1123.000000       0.004849          1
# 2664  1124.000000       0.004860          1
#
# [2665 rows x 8 columns]

# %% [markdown]
# ## data_test_2

# %%
data_test_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9752 entries, 0 to 9751
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             9752 non-null   int64
#  1   date           9752 non-null   object
#  2   Temperature    9752 non-null   float64
#  3   Humidity       9752 non-null   float64
#  4   Light          9752 non-null   float64
#  5   CO2            9752 non-null   float64
#  6   HumidityRatio  9752 non-null   float64
#  7   Occupancy      9752 non-null   int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 609.6+ KB

# %%
data_test_2.head(9752)
# Out:
#         id                 date  Temperature   Humidity       Light  \
# 0        1  2015-02-11 14:48:00      21.7600  31.133333  437.333333
# 1        2  2015-02-11 14:49:00      21.7900  31.000000  437.333333
# 2        3  2015-02-11 14:50:00      21.7675  31.122500  434.000000
# 3        4  2015-02-11 14:51:00      21.7675  31.122500  439.000000
# 4        5  2015-02-11 14:51:59      21.7900  31.133333  437.333333
# ...    ...                  ...          ...        ...         ...
# 9747  9748  2015-02-18 09:15:00      20.8150  27.717500  429.750000
# 9748  9749  2015-02-18 09:16:00      20.8650  27.745000  423.500000
# 9749  9750  2015-02-18 09:16:59      20.8900  27.745000  423.500000
# 9750  9751  2015-02-18 09:17:59      20.8900  28.022500  418.750000
# 9751  9752  2015-02-18 09:19:00      21.0000  28.100000  409.000000
#
#               CO2  HumidityRatio  Occupancy
# 0     1029.666667       0.005021          1
# 1     1000.000000       0.005009          1
# 2     1003.750000       0.005022          1
# 3     1009.500000       0.005022          1
# 4     1005.666667       0.005030          1
# ...           ...            ...        ...
# 9747  1505.250000       0.004213          1
# 9748  1514.500000       0.004230          1
# 9749  1521.500000       0.004237          1
# 9750  1632.000000       0.004279          1
# 9751  1864.000000       0.004321          1
#
# [9752 rows x 8 columns]

# %% [markdown]
# # Variables

# %%
plt.figure(figsize=(10, 6))
box = plt.boxplot(
  x=[data_training[attr_name], data_test_1[attr_name], data_test_2[attr_name]], 
  patch_artist=True,
  tick_labels=["Data Training", "Data Test 1", "Data Test 2"]
)

colors = ['#9fd0ac', p_color, '#9fc3d0']

for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

# Change median line color
for median in box['medians']:
    median.set_color(t_color)

# Set axis labels and title
plt.xlabel("Dataset")
plt.ylabel(attr_name)
plt.title(attr_name)

# Set background color to none
plt.gca().set_facecolor("none")
plt.gcf().set_facecolor("none")

# Show plot
plt.show()

# %% [markdown]
# ## Temperature

# %%
attr_name = 'Temperature'

# %% [markdown]
# ### data_training

# %%
result = data_training[attr_name]

# Show Parameters
table = []

print('Data Training Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Training Parameters:  Temperature
# +-----------+---------+
# |           |   Value |
# +===========+=========+
# | Skewness: |  0.4509 |
# +-----------+---------+
# | Mean:     | 20.6191 |
# +-----------+---------+
# | Median:   | 20.39   |
# +-----------+---------+
# | Mode:     | 19.39   |
# +-----------+---------+
# | SD:       |  1.0169 |
# +-----------+---------+
# | Variance: |  1.0341 |
# +-----------+---------+
# | Min:      | 19      |
# +-----------+---------+
# | Q₁:       | 19.7    |
# +-----------+---------+
# | Q₂:       | 20.39   |
# +-----------+---------+
# | Q₃:       | 21.39   |
# +-----------+---------+
# | Max:      | 23.18   |
# +-----------+---------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l', showfliers=True)
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 17.165
# Upper Bound 23.925000000000004

# %% [markdown]
# ### data_test_1

# %%
result = data_test_1[attr_name]

# Show Parameters
table = []

print('Data Test 1 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 1 Parameters:  Temperature
# +-----------+---------+
# |           |   Value |
# +===========+=========+
# | Skewness: |  0.8426 |
# +-----------+---------+
# | Mean:     | 21.4339 |
# +-----------+---------+
# | Median:   | 20.89   |
# +-----------+---------+
# | Mode:     | 20.7    |
# +-----------+---------+
# | SD:       |  1.028  |
# +-----------+---------+
# | Variance: |  1.0568 |
# +-----------+---------+
# | Min:      | 20.2    |
# +-----------+---------+
# | Q₁:       | 20.65   |
# +-----------+---------+
# | Q₂:       | 20.89   |
# +-----------+---------+
# | Q₃:       | 22.3567 |
# +-----------+---------+
# | Max:      | 24.4083 |
# +-----------+---------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 18.089999999999947
# Upper Bound 24.916666666666757

# %% [markdown]
# ### data_test_2

# %%
result = data_test_2[attr_name]

# Show Parameters
table = []

print('Data Test 1 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 1 Parameters:  Temperature
# +-----------+---------+
# |           |   Value |
# +===========+=========+
# | Skewness: |  1.2283 |
# +-----------+---------+
# | Mean:     | 21.0018 |
# +-----------+---------+
# | Median:   | 20.79   |
# +-----------+---------+
# | Mode:     | 20.39   |
# +-----------+---------+
# | SD:       |  1.0207 |
# +-----------+---------+
# | Variance: |  1.0418 |
# +-----------+---------+
# | Min:      | 19.5    |
# +-----------+---------+
# | Q₁:       | 20.29   |
# +-----------+---------+
# | Q₂:       | 20.79   |
# +-----------+---------+
# | Q₃:       | 21.5333 |
# +-----------+---------+
# | Max:      | 24.39   |
# +-----------+---------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 18.425000000000047
# Upper Bound 23.398333333333248

# %% [markdown]
# ### Relationships

# %% [markdown]
# ## Humidity

# %%
attr_name = 'Humidity'

# %% [markdown]
# ### data_training

# %%
result = data_training[attr_name]

# Show Parameters
table = []

print('Data Training Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Training Parameters:  Humidity
# +-----------+---------+
# |           |   Value |
# +===========+=========+
# | Skewness: |  0.272  |
# +-----------+---------+
# | Mean:     | 25.7315 |
# +-----------+---------+
# | Median:   | 26.2225 |
# +-----------+---------+
# | Mode:     | 33      |
# +-----------+---------+
# | SD:       |  5.5312 |
# +-----------+---------+
# | Variance: | 30.5943 |
# +-----------+---------+
# | Min:      | 16.745  |
# +-----------+---------+
# | Q₁:       | 20.2    |
# +-----------+---------+
# | Q₂:       | 26.2225 |
# +-----------+---------+
# | Q₃:       | 30.5333 |
# +-----------+---------+
# | Max:      | 39.1175 |
# +-----------+---------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l', showfliers=True)
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 4.700000000000049
# Upper Bound 46.033333333333246

# %% [markdown]
# ### data_test_1

# %%
result = data_test_1[attr_name]

# Show Parameters
table = []

print('Data Test 1 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 1 Parameters:  Humidity
# +-----------+---------+
# |           |   Value |
# +===========+=========+
# | Skewness: |  0.6728 |
# +-----------+---------+
# | Mean:     | 25.3539 |
# +-----------+---------+
# | Median:   | 25      |
# +-----------+---------+
# | Mode:     | 22.5    |
# +-----------+---------+
# | SD:       |  2.4368 |
# +-----------+---------+
# | Variance: |  5.9382 |
# +-----------+---------+
# | Min:      | 22.1    |
# +-----------+---------+
# | Q₁:       | 23.26   |
# +-----------+---------+
# | Q₂:       | 25      |
# +-----------+---------+
# | Q₃:       | 26.8567 |
# +-----------+---------+
# | Max:      | 31.4725 |
# +-----------+---------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 17.864999999999952
# Upper Bound 32.25166666666675

# %% [markdown]
# ### data_test_2

# %%
result = data_test_2[attr_name]

# Show Parameters
table = []

print('Data Test 2 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 2 Parameters:  Humidity
# +-----------+---------+
# |           |   Value |
# +===========+=========+
# | Skewness: |  0.1193 |
# +-----------+---------+
# | Mean:     | 29.8919 |
# +-----------+---------+
# | Median:   | 30.2    |
# +-----------+---------+
# | Mode:     | 30.39   |
# +-----------+---------+
# | SD:       |  3.9528 |
# +-----------+---------+
# | Variance: | 15.625  |
# +-----------+---------+
# | Min:      | 21.865  |
# +-----------+---------+
# | Q₁:       | 26.6421 |
# +-----------+---------+
# | Q₂:       | 30.2    |
# +-----------+---------+
# | Q₃:       | 32.7    |
# +-----------+---------+
# | Max:      | 39.5    |
# +-----------+---------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 17.555208333333308
# Upper Bound 41.78687500000002

# %% [markdown]
# ## Light

# %%
attr_name = 'Light'

# %% [markdown]
# ### data_training

# %%
result = data_training[attr_name]

# Show Parameters
table = []

print('Data Training Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Training Parameters:  Light
# +-----------+-------------------+
# |           | Value             |
# +===========+===================+
# | Skewness: | 1.2374            |
# +-----------+-------------------+
# | Mean:     | 119.5194          |
# +-----------+-------------------+
# | Median:   | 0.0000            |
# +-----------+-------------------+
# | Mode:     | 0.0               |
# +-----------+-------------------+
# | SD:       | 194.7558          |
# +-----------+-------------------+
# | Variance: | 37,929.8235       |
# +-----------+-------------------+
# | Min:      | 0.0               |
# +-----------+-------------------+
# | Q₁:       | 0.0000            |
# +-----------+-------------------+
# | Q₂:       | 0.0000            |
# +-----------+-------------------+
# | Q₃:       | 256.3750          |
# +-----------+-------------------+
# | Max:      | 1,546.33333333333 |
# +-----------+-------------------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l', showfliers=True)
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound -384.5625
# Upper Bound 640.9375

# %% [markdown]
# ### data_test_1

# %%
result = data_test_1[attr_name]

# Show Parameters
table = []

print('Data Test 1 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 1 Parameters:  Light
# +-----------+-------------+
# |           | Value       |
# +===========+=============+
# | Skewness: | 0.7599      |
# +-----------+-------------+
# | Mean:     | 193.2276    |
# +-----------+-------------+
# | Median:   | 0.0000      |
# +-----------+-------------+
# | Mode:     | 0.0         |
# +-----------+-------------+
# | SD:       | 250.2109    |
# +-----------+-------------+
# | Variance: | 62,605.4974 |
# +-----------+-------------+
# | Min:      | 0.0         |
# +-----------+-------------+
# | Q₁:       | 0.0000      |
# +-----------+-------------+
# | Q₂:       | 0.0000      |
# +-----------+-------------+
# | Q₃:       | 442.5000    |
# +-----------+-------------+
# | Max:      | 1,697.25    |
# +-----------+-------------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound -663.75
# Upper Bound 1106.25

# %% [markdown]
# ### data_test_2

# %%
result = data_test_2[attr_name]

# Show Parameters
table = []

print('Data Test 2 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 2 Parameters:  Light
# +-----------+-------------+
# |           | Value       |
# +===========+=============+
# | Skewness: | 1.5121      |
# +-----------+-------------+
# | Mean:     | 123.0679    |
# +-----------+-------------+
# | Median:   | 0.0000      |
# +-----------+-------------+
# | Mode:     | 0.0         |
# +-----------+-------------+
# | SD:       | 208.2213    |
# +-----------+-------------+
# | Variance: | 43,356.0994 |
# +-----------+-------------+
# | Min:      | 0.0         |
# +-----------+-------------+
# | Q₁:       | 0.0000      |
# +-----------+-------------+
# | Q₂:       | 0.0000      |
# +-----------+-------------+
# | Q₃:       | 208.2500    |
# +-----------+-------------+
# | Max:      | 1,581.0     |
# +-----------+-------------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound -312.375
# Upper Bound 520.625

# %% [markdown]
# ## CO2

# %%
attr_name = 'CO2'

# %% [markdown]
# ### data_training

# %%
result = data_training[attr_name]

# Show Parameters
table = []

print('Data Training Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Training Parameters:  CO2
# +-----------+-------------+
# |           | Value       |
# +===========+=============+
# | Skewness: | 2.3809      |
# +-----------+-------------+
# | Mean:     | 606.5462    |
# +-----------+-------------+
# | Median:   | 453.5000    |
# +-----------+-------------+
# | Mode:     | 439.0       |
# +-----------+-------------+
# | SD:       | 314.3209    |
# +-----------+-------------+
# | Variance: | 98,797.6136 |
# +-----------+-------------+
# | Min:      | 412.75      |
# +-----------+-------------+
# | Q₁:       | 439.0000    |
# +-----------+-------------+
# | Q₂:       | 453.5000    |
# +-----------+-------------+
# | Q₃:       | 638.8333    |
# +-----------+-------------+
# | Max:      | 2,028.5     |
# +-----------+-------------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l', showfliers=True)
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 139.24999999999977
# Upper Bound 938.5833333333337

# %% [markdown]
# ### data_test_1

# %%
result = data_test_1[attr_name]

# Show Parameters
table = []

print('Data Test 1 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 1 Parameters:  CO2
# +-----------+-------------+
# |           | Value       |
# +===========+=============+
# | Skewness: | 0.7876      |
# +-----------+-------------+
# | Mean:     | 717.9065    |
# +-----------+-------------+
# | Median:   | 580.5000    |
# +-----------+-------------+
# | Mode:     | 436.0       |
# +-----------+-------------+
# | SD:       | 292.6817    |
# +-----------+-------------+
# | Variance: | 85,662.5883 |
# +-----------+-------------+
# | Min:      | 427.5       |
# +-----------+-------------+
# | Q₁:       | 466.0000    |
# +-----------+-------------+
# | Q₂:       | 580.5000    |
# +-----------+-------------+
# | Q₃:       | 956.3333    |
# +-----------+-------------+
# | Max:      | 1,402.25    |
# +-----------+-------------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound -269.49999999999955
# Upper Bound 1691.8333333333326

# %% [markdown]
# ### data_test_2

# %%
result = data_test_2[attr_name]

# Show Parameters
table = []

print('Data Test 2 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 2 Parameters:  CO2
# +-----------+------------------+
# |           | Value            |
# +===========+==================+
# | Skewness: | 1.5454           |
# +-----------+------------------+
# | Mean:     | 753.2248         |
# +-----------+------------------+
# | Median:   | 639.0000         |
# +-----------+------------------+
# | Mode:     | 503.0            |
# +-----------+------------------+
# | SD:       | 297.0961         |
# +-----------+------------------+
# | Variance: | 88,266.1007      |
# +-----------+------------------+
# | Min:      | 484.666666666667 |
# +-----------+------------------+
# | Q₁:       | 542.3125         |
# +-----------+------------------+
# | Q₂:       | 639.0000         |
# +-----------+------------------+
# | Q₃:       | 831.1250         |
# +-----------+------------------+
# | Max:      | 2,076.5          |
# +-----------+------------------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 109.09374999999943
# Upper Bound 1264.3437500000005

# %% [markdown]
# ## Humidity Ratio

# %%
attr_name = 'HumidityRatio'

# %% [markdown]
# ### data_training

# %%
result = data_training[attr_name]

# Show Parameters
table = []

print('Data Training Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Training Parameters:  HumidityRatio
# +-----------+------------+
# |           |      Value |
# +===========+============+
# | Skewness: | 0.6167     |
# +-----------+------------+
# | Mean:     | 0.0039     |
# +-----------+------------+
# | Median:   | 0.0038     |
# +-----------+------------+
# | Mode:     | 0.00484625 |
# +-----------+------------+
# | SD:       | 0.0009     |
# +-----------+------------+
# | Variance: | 0          |
# +-----------+------------+
# | Min:      | 0.00267413 |
# +-----------+------------+
# | Q₁:       | 0.0031     |
# +-----------+------------+
# | Q₂:       | 0.0038     |
# +-----------+------------+
# | Q₃:       | 0.0044     |
# +-----------+------------+
# | Max:      | 0.00647601 |
# +-----------+------------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l', showfliers=True)
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 0.0011678153605354743
# Upper Bound 0.006262399252388076

# %% [markdown]
# ### data_test_1

# %%
result = data_test_1[attr_name]

# Show Parameters
table = []

print('Data Test 1 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 1 Parameters:  HumidityRatio
# +-----------+------------+
# |           |      Value |
# +===========+============+
# | Skewness: | 0.6494     |
# +-----------+------------+
# | Mean:     | 0.004      |
# +-----------+------------+
# | Median:   | 0.0038     |
# +-----------+------------+
# | Mode:     | 0.00332676 |
# +-----------+------------+
# | SD:       | 0.0006     |
# +-----------+------------+
# | Variance: | 0          |
# +-----------+------------+
# | Min:      | 0.00330331 |
# +-----------+------------+
# | Q₁:       | 0.0035     |
# +-----------+------------+
# | Q₂:       | 0.0038     |
# +-----------+------------+
# | Q₃:       | 0.0045     |
# +-----------+------------+
# | Max:      | 0.00537776 |
# +-----------+------------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 0.0020264018709621008
# Upper Bound 0.006034614461188499

# %% [markdown]
# ### data_test_2

# %%
result = data_test_2[attr_name]

# Show Parameters
table = []

print('Data Test 2 Parameters: ', attr_name)
table.append(['Skewness: ', f"{result.skew():,.4f}"])
table.append(['Mean: ', f"{result.mean():,.4f}"])
table.append(['Median: ', f"{result.median():,.4f}"])
table.append(['Mode: ', f"{result.mode().iloc[0]:,}"])
table.append(['SD: ', f"{result.std():,.4f}"])
table.append(['Variance: ', f"{result.var():,.4f}"])
table.append(['Min: ', f"{result.min():,}"])
table.append(['Q₁: ', f"{result.quantile(.25):,.4f}"])
table.append(['Q₂: ', f"{result.quantile(.50):,.4f}"])
table.append(['Q₃: ', f"{result.quantile(.75):,.4f}"])
table.append(['Max: ', f"{result.max():,}"])

print(tabulate(table, headers=['', 'Value'], tablefmt='grid'))
# Out:
# Data Test 2 Parameters:  HumidityRatio
# +-----------+-------------+
# |           |       Value |
# +===========+=============+
# | Skewness: | -0.167      |
# +-----------+-------------+
# | Mean:     |  0.0046     |
# +-----------+-------------+
# | Median:   |  0.0046     |
# +-----------+-------------+
# | Mode:     |  0.00508894 |
# +-----------+-------------+
# | SD:       |  0.0005     |
# +-----------+-------------+
# | Variance: |  0          |
# +-----------+-------------+
# | Min:      |  0.00327476 |
# +-----------+-------------+
# | Q₁:       |  0.0042     |
# +-----------+-------------+
# | Q₂:       |  0.0046     |
# +-----------+-------------+
# | Q₃:       |  0.005      |
# +-----------+-------------+
# | Max:      |  0.00576861 |
# +-----------+-------------+

# %%
# Show Histogram
result.hist(bins=10, color=p_color).set_facecolor("none")

ax = plt.gca()
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)
ax.tick_params(axis='both', colors=t_color)

plt.gcf().set_facecolor("none")
# plt.savefig(attr_name + '_histogram.png', transparent=True)
plt.show()

# %%
# สร้าง boxplot แนวนอนและปรับขนาด
plt.figure(figsize=(8, 10))
ax = sns.boxplot(data=result, color=p_color, orient='l')
ax.set_facecolor("none")

# ปรับสีของ spines (เส้นขอบกราฟ)
ax.spines['top'].set_color(s_color)
ax.spines['right'].set_color(s_color)
ax.spines['left'].set_color(s_color)
ax.spines['bottom'].set_color(s_color)

# ปรับสีของ ticks และ labels
ax.tick_params(axis='both', colors=t_color)

# ปรับสีของ figure
plt.gcf().set_facecolor("none")
plt.show()

Q1 = result.quantile(0.25)
Q3 = result.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print('Lower Bound', lower_bound)
print('Upper Bound', upper_bound)
# Out:
# Lower Bound 0.0029938194496024746
# Upper Bound 0.006200453381360476
